# %%
import base64
for f in ["genetic_graph_1.png","genetic_graph_2.png","genetic_graph_3.png",
          "trajectory_graph_1.png","trajectory_dist_1.png",
          "trajectory_graph_2.png","trajectory_dist_2.png",
          "trajectory_graph_3.png","trajectory_dist_3.png"]:
    with open(f,"rb") as img:
        print(f, base64.b64encode(img.read()).decode()[:30]+"...")
# Out:
# genetic_graph_1.png iVBORw0KGgoAAAANSUhEUgAAAxQAAA...
# genetic_graph_2.png iVBORw0KGgoAAAANSUhEUgAAAxUAAA...
# genetic_graph_3.png iVBORw0KGgoAAAANSUhEUgAAAxYAAA...
# trajectory_graph_1.png iVBORw0KGgoAAAANSUhEUgAABW0AAA...
# trajectory_dist_1.png iVBORw0KGgoAAAANSUhEUgAAA3kAAA...
# trajectory_graph_2.png iVBORw0KGgoAAAANSUhEUgAABW0AAA...
# trajectory_dist_2.png iVBORw0KGgoAAAANSUhEUgAAA3kAAA...
# trajectory_graph_3.png iVBORw0KGgoAAAANSUhEUgAABW0AAA...
# trajectory_dist_3.png iVBORw0KGgoAAAANSUhEUgAAA3kAAA...

# %% [markdown]
# ## Genetic Algorithm — abz5
# ![](genetic_graph_1.png)
#
#
# We can see that x1 has the best record, but more importantly we look at the average and we can conclude that its tied with x3.
# The difference was just in the pop_size 300 on x1 and 550 on x3. X3 has higher runtime
#
# ## Genetic Algorithm — abz6
# ![](genetic_graph_2.png)
#
#
# x3 has the best results and the best averages, but it is very close.
#  But if we look at runtime we can see that at the same time x3 has the highest.
#
# ## Genetic Algorithm — abz7
# ![](genetic_graph_3.png)
#
#
# Again we have similar discussion, x3 lays on the lower end on avg&best but yields the highest time due to the highest pop size.
# We can really see that genetic algorithms are computationally demanding here

# %% [markdown]
# ## Trajectory Hill Climbing Algorithm — abz5
# ![](trajectory_graph_1.png)
#
# ![](trajectory_dist_1.png)
#
#
#
# Your explanation here...
#
# ## Trajectory Hill Climbing Algorithm — abz6
# ![](trajectory_graph_2.png)
#
# ![](trajectory_dist_2.png)
#
#
#
# Your explanation here...
#
#
# ## Trajectory Hill Climbing Algorithm — abz6
# ![](trajectory_graph_3.png)
#
# ![](trajectory_dist_3.png)
#
#
#
# Your explanation here...

# %% [markdown]
# ## Conclusion
#
# Aspects:
#
# Search styles - Hill climbing uses a search style more of a form of exploitation, it tries to improve it's current solution. While GA also does abit of exploitation but this happens towards the end, in the beginning it explores differnt solutions trying to achieve a bigger variety.
#
# Optimum - Hill climbing can easily get trapped in a local optimum, while GA is more resistant because it is more diverse. Basically GA has much more data to work with and therefore more alternatives which prevents it from being stuck unlike Hill climbing that does not have as many alternatives.
#
# Convergence speed - Hill climbing converges fast and early which yields faster results but not always does it prioritize quality. GA is usually slower but towards the end it will yield higher Quality, in this area we sacrifice time for quality.
#
# Computational cost - As mentioned above GA has a higher computational cost than Hill climbing.
